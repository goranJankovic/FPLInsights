# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("fpl_data.db")

query = """
SELECT
    players.first_name || ' ' || players.second_name AS name,
    players.now_cost,
    players.selected_by_percent,
    teams.name AS team_name,
    element_types.name as position
FROM players
JOIN teams ON players.team_id = teams.id
JOIN element_types ON players.element_type = element_types.id
WHERE selected_by_percent > 10 and now_cost < 6
ORDER BY selected_by_percent DESC
LIMIT 10
"""

df = pd.read_sql_query(query, conn)
df
# Out:
#                                name  now_cost  selected_by_percent  \
# 0                 Caoimhín Kelleher       4.5                 32.2
# 1                 Aaron Wan-Bissaka       4.5                 32.1
# 2                  Ezri Konsa Ngoyo       4.5                 24.0
# 3                 David Raya Martín       5.5                 18.6
# 4                          Ola Aina       5.0                 18.2
# 5                         Matz Sels       5.0                 17.8
# 6  Norberto Bercique Gomes Betuncal       5.5                 15.6
# 7                        Marc Guéhi       4.5                 13.7
# 8              Robert Lynch Sánchez       5.0                 13.5
# 9                  Micky van de Ven       4.5                 13.4
#
#         team_name     position
# 0       Brentford  Goalkeepers
# 1        West Ham    Defenders
# 2     Aston Villa    Defenders
# 3         Arsenal  Goalkeepers
# 4   Nott'm Forest    Defenders
# 5   Nott'm Forest  Goalkeepers
# 6         Everton     Forwards
# 7  Crystal Palace    Defenders
# 8         Chelsea  Goalkeepers
# 9           Spurs    Defenders

# %%
# %%sql
# WITH next_opponents AS (
#     SELECT
#         f.id,
#         f.event,
#         CASE
#             WHEN f.home_team = t.id THEN f.away_team
#             ELSE f.home_team
#         END AS opponent_id,
#         t.id as team_id
#     FROM fixtures f
#     JOIN teams t ON t.id = f.home_team OR t.id = f.away_team
#     WHERE f.event IN (1, 2, 3)
# ),
# opponents_named AS (
#     SELECT
#         nf.team_id,
#         GROUP_CONCAT(t2.name, ', ') as next_opponents
#     FROM next_opponents nf
#     JOIN teams t2 ON t2.id = nf.opponent_id
#     GROUP BY nf.team_id
# )
# SELECT
#     p.first_name || ' ' || p.second_name AS name,
#     p.now_cost,
#     p.selected_by_percent,
#     t.name AS team_name,
#     et.name AS position,
#     o.next_opponents
# FROM players p
# JOIN teams t ON p.team_id = t.id
# JOIN element_types et ON p.element_type = et.id
# LEFT JOIN opponents_named o ON o.team_id = p.team_id
# WHERE p.element_type = 1 AND p.now_cost <= 4.0
# ORDER BY p.selected_by_percent DESC
# LIMIT 30;
# Out:
#                                 name  now_cost  selected_by_percent  \
# 0                    Martin Dúbravka         4                 11.3
# 1                        Karl Darlow         4                  8.2
# 2                     Antonín Kinský         4                  6.2
# 3                           Tom King         4                  3.3
# 4            Hákon Rafn Valdimarsson         4                  2.2
# 5                        Matt Turner         4                  1.5
# 6                     Daniel Bentley         4                  1.1
# 7                          Joe Gauci         4                  1.0
# 8                    Wes Foderingham         4                  1.0
# 9                        Will Dennis         4                  0.7
# 10                       Simon Moore         4                  0.7
# 11                         Karl Hein         4                  0.6
# 12                  Benjamin Lecomte         4                  0.6
